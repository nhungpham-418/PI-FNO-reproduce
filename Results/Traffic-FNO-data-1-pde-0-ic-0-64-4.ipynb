# %%
import torch
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt

# %cd ..
from models import FNO2d
from train_utils.datasets import MatReader, TrafficLoader

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# /home/tp526/neuraloperator/PI-FNO-reproduce

# %% [markdown]
# <h2>Load model</h2>

# %%
config = {"model": {
              "layers": [16, 16, 24, 32], #[24, 32, 32, 64], #[16, 24, 24, 32, 32],
              "modes1": [8, 6, 4], #[15, 12, 9, 9],
              "modes2": [8, 6, 4], #[15, 12, 9, 9],
              "fc_dim": 32, #128,
              "act": "gelu",
              "num_pad": 4,
            },
          }

# %%
model = FNO2d(modes1=config['model']['modes1'],
              modes2=config['model']['modes2'],
              fc_dim=config['model']['fc_dim'],
              layers=config['model']['layers'],
              act=config['model']['act']).to(device)

# ckpt_path = "/home/tp526/neuraloperator/PI-FNO-reproduce/checkpoints/traffic-FDM/traffic-data-1-pde-0-ic-0-4-16-mode-8-x100.pt"

ckpt_path = "/home/tp526/neuraloperator/PI-FNO-reproduce/checkpoints/traffic-FDM/traffic-pde-1-ic-100-4-32-mode-8-physics.pt"

ckpt = torch.load(ckpt_path)
model.load_state_dict(ckpt['model'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# <h2>Generate Ground Truths</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def solve_t_traffic_sharp(u0, x_max=1.0, t_max=1.0, Nx=500, Nt=None, cfl=0.8, plot=False):
    dx = x_max / Nx
    x = np.linspace(0, x_max, Nx, endpoint=False)
    
    # Estimate dt based on max possible wave speed (approx 0.5 for this traffic model)
    # and max time t_max.
    if Nt is None:
        max_speed_est = t_max * 0.5 
        dt = cfl * dx / max_speed_est
        Nt = int(t_max / dt) + 1
    else:
        dt = t_max / (Nt - 1)

    # --- Physics Functions ---
    def g_flux_spatial(u):
        return (u**2)/2.0 - (u**3)/6.0
    
    def g_prime_spatial(u):
        return u - (u**2)/2.0

    # --- Minmod Slope Limiter (The key to sharpness) ---
    def minmod(a, b):
        return np.where(np.abs(a) < np.abs(b), a, b) * (np.sign(a) == np.sign(b))

    u = u0
    sols = [u.copy()]

    for n in range(Nt):
        current_time = n * dt
        
        # --- 1. Slope Reconstruction ---
        # Get neighbors with periodic boundary conditions
        u_minus = np.roll(u, 1)
        u_plus  = np.roll(u, -1)
        
        # Calculate slopes (difference between neighbors)
        slope_L = (u - u_minus) / dx
        slope_R = (u_plus - u) / dx
        
        # Apply Limiter to avoid oscillations at shocks
        sigma = minmod(slope_L, slope_R)
        
        # Reconstruct values at the boundaries (Left and Right of the interface)
        # u_L_interface is the value at i+1/2 coming from cell i
        # u_R_interface is the value at i+1/2 coming from cell i+1
        u_L_interface = u + 0.5 * dx * sigma
        u_R_interface = u_plus - 0.5 * dx * np.roll(sigma, -1)
        
        # --- 2. Rusanov Flux using RECONSTRUCTED values ---
        flux_L = g_flux_spatial(u_L_interface)
        flux_R = g_flux_spatial(u_R_interface)
        
        # Calculate wave speed (alpha) using the max speed at the interface
        # We check both sides of the interface to be safe
        speed_L = np.abs(g_prime_spatial(u_L_interface))
        speed_R = np.abs(g_prime_spatial(u_R_interface))
        alpha = current_time * np.maximum(speed_L, speed_R)
        
        # Rusanov Flux Formula
        F_interface = 0.5 * (current_time * (flux_L + flux_R) - alpha * (u_R_interface - u_L_interface))
        
        # --- 3. Update Solution ---
        dF = F_interface - np.roll(F_interface, 1)
        u = u - (dt / dx) * dF
        
        sols.append(u.copy())

    if plot:
        plt.figure(figsize=(12,5))
        plt.subplot(1,2,1)
        plt.plot(x, sols[-1], label="High-Res Solution", color='red')
        plt.plot(x, ic(x), '--', label="Initial condition", color='gray', alpha=0.5)
        plt.title(r'Sharper Solution (MUSCL)')
        plt.legend()
        plt.grid()

        plt.subplot(1,2,2)
        plt.imshow(sols, extent=[0, x_max, 0, t_max], origin="lower", aspect="auto", cmap="jet")
        plt.colorbar()
        plt.show()

    return np.array(sols)

def create_traffic_dataset(N_SAMPLES=200, Nx=128, Nt=101, X_MUL=4, T_MUL=5, LENGTH_SCALE=1.0, ics=None):
    """
    Generates dataset and returns dictionary with NumPy arrays.
    """
    print(f"Generating {N_SAMPLES} samples of time-dependent traffic equation ...")
    
    # Pre-allocate arrays
    x_data = np.zeros((N_SAMPLES, Nx))      # To store Initial Conditions
    y_data = np.zeros((N_SAMPLES, Nt, Nx))  # To store Solutions

    func_space = dde.data.GRF(kernel="ExpSineSquared", length_scale=LENGTH_SCALE)
    feats = func_space.random(N_SAMPLES)

    xs = np.linspace(0, 1, Nx*X_MUL)
    if ics is not None:
        ics_all = np.zeros((N_SAMPLES, Nx*X_MUL))
        # interpolate ics to match the resolution
        x_res = ics.shape[1]
        x_grid = np.linspace(0, 1, x_res+1, endpoint=True)
        for k in range(N_SAMPLES):
            ic_pad = np.append(ics[k], ics[k][0])
            ic = interp1d(x_grid, ic_pad, "linear")
            ics_all[k] = ic(xs)

    else:  
        ics_all = func_space.eval_batch(feats, xs)
    
    for i in range(N_SAMPLES):
        if (i+1) % 50 == 0:
            print(f"Processing sample {i+1}/{N_SAMPLES}...")
            
        # 1. Generate IC
        u0 = ics_all[i]
        
        # 2. Solve
        u_sol = solve_t_traffic_sharp(u0, Nx=Nx*X_MUL, Nt=(Nt-1)*T_MUL+1)
        
        # 3. Store
        x_data[i] = u0[::X_MUL]
        y_data[i] = u_sol[::T_MUL, ::X_MUL]

    # 4. Pack into dictionary (NumPy arrays only)
    traffic_128 = {
        'x': x_data,
        'y': y_data,
        'visc': np.array([[0]])
    }
    
    print("\nGeneration complete.")
    print(f"x shape: {traffic_128['x'].shape}")
    print(f"y shape: {traffic_128['y'].shape}")
    
    return traffic_128

# --- Example Usage ---
if __name__ == "__main__":
    # Generate data
    data_dict = create_traffic_dataset(N_SAMPLES=100, Nx=128, Nt=101, X_MUL=4, T_MUL=50)
    
    # Verification Plot
    sample_idx = np.random.randint(1)
    x_grid = np.linspace(0, 1, 128)
    u_field = data_dict['y'][sample_idx]
    
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)    
    plt.plot(x_grid, u_field[0], label="Initial")
    plt.plot(x_grid, u_field[-1], label="Final")
    plt.title("Initial versus Final states")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.imshow(u_field, extent=[0, 1, 0, 1], origin="lower", aspect="auto", cmap="jet")
    plt.colorbar(label="u(x,t)")
    plt.title(f"Sample {sample_idx} Solution Heatmap")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.show()
# Out:
# Generating 100 samples of time-dependent traffic equation ...
# Processing sample 50/100...
# Processing sample 100/100...
#
# Generation complete.
# x shape: (100, 128)
# y shape: (100, 101, 128)

# %%
# # Generate data
# data_dict = create_traffic_dataset(N_SAMPLES=1000, Nx=128, Nt=101, X_MUL=4, T_MUL=50)

# import scipy

# # We map 'x' -> 'input' and 'y' -> 'output'
# mat_data = {
#     'input': data_dict['x'],
#     'output': data_dict['y'],
#     'visc': data_dict['visc']
# }

# # 3. Save to .mat file
# # do_compression=True helps if the arrays are large
# scipy.io.savemat('/home/tp526/neuraloperator/data/traffic_pino.mat', mat_data, do_compression=True)

# print("Saved to /home/tp526/neuraloperator/data/traffic_pino.mat")
# Out:
# Generating 1000 samples of time-dependent traffic equation ...
# Processing sample 50/1000...
# Processing sample 100/1000...
# Processing sample 150/1000...
# Processing sample 200/1000...
# Processing sample 250/1000...
# Processing sample 300/1000...
# Processing sample 350/1000...
# Processing sample 400/1000...
# Processing sample 450/1000...
# Processing sample 500/1000...
# Processing sample 550/1000...
# Processing sample 600/1000...
# Processing sample 650/1000...
# Processing sample 700/1000...
# Processing sample 750/1000...
# Processing sample 800/1000...
# Processing sample 850/1000...
# Processing sample 900/1000...
# Processing sample 950/1000...
# Processing sample 1000/1000...
#
# Generation complete.
# x shape: (1000, 128)
# y shape: (1000, 101, 128)
# Saved to /home/tp526/neuraloperator/data/traffic_pino.mat

# %% [markdown]
# <h2>Test the model</h2>

# %%
def format_burgers_data(data_dict):
    """
    Reshapes the Burgers dataset into a coordinate-based format.
    
    Args:
        data_dict (dict): Dictionary with keys 'x' (N, Nx) and 'y' (N, Nt, Nx).
        
    Returns:
        np.array: A single array of shape (N_SAMPLES, Nt, Nx, 3).
                  Channel 0: u0(x) repeated over time
                  Channel 1: x coordinates
                  Channel 2: t coordinates
    """
    # 1. Extract dimensions
    # data_dict['x'] is the initial condition u0, shape (N, Nx)
    # data_dict['y'] is the solution u, shape (N, Nt, Nx)
    u0 = data_dict['x'] 
    N_samples, Nx = u0.shape
    Nt = data_dict['y'].shape[1]
    
    print(f"Dimensions detected: N={N_samples}, Nt={Nt}, Nx={Nx}")

    # 2. Create Mesh Grids (Nt, Nx)
    # Recreate the grids used in the solver
    x_1d = np.linspace(0, 1, Nx, endpoint=False)
    t_1d = np.linspace(0, 1, Nt)
    
    # Create 2D grids. indexing='ij' ensures output is (Nt, Nx)
    # T_grid varies along axis 0, X_grid varies along axis 1
    T_grid, X_grid = np.meshgrid(t_1d, x_1d, indexing='ij')
    
    # 3. Broadcast/Repeat Arrays to shape (N, Nt, Nx)
    
    # Channel 0: u0 (Initial Condition)
    # Input: (N, Nx) -> Expand to (N, 1, Nx) -> Tile to (N, Nt, Nx)
    u0_expanded = np.tile(u0[:, None, :], (1, Nt, 1))
    
    # Channel 1: X Grid
    # Input: (Nt, Nx) -> Expand to (1, Nt, Nx) -> Broadcast to (N, Nt, Nx)
    X_expanded = np.tile(X_grid[None, :, :], (N_samples, 1, 1))
    
    # Channel 2: T Grid
    # Input: (Nt, Nx) -> Expand to (1, Nt, Nx) -> Broadcast to (N, Nt, Nx)
    T_expanded = np.tile(T_grid[None, :, :], (N_samples, 1, 1))
    
    # 4. Stack along the last axis
    # Result shape: (N, Nt, Nx, 3, 1)
    formatted_data = np.stack([u0_expanded, X_expanded, T_expanded], axis=-1)
    
    return formatted_data

# %%
# Load the test data
import scipy.io

# Load the file
mat_data = scipy.io.loadmat('../data/test_data/traffic_test_x100_t101_1000.mat')

data_dict = {
    'x' : mat_data['input'],
    'y' : mat_data['output']
}

formatted_inputs = format_burgers_data(data_dict)
formatted_inputs.shape
# Out:
# Dimensions detected: N=1000, Nt=101, Nx=100
# (1000, 101, 100, 3)

# %%
k = np.random.randint(10)

x, y = torch.tensor(formatted_inputs[k:k+1], dtype=torch.float32).to(device), torch.tensor(data_dict["y"][k:k+1], dtype=torch.float32).to(device)

print("Input shape: ", x.shape)
print("Output shape: ", y.shape)
print("\n")

out = model(x).reshape(y.shape)

data_loss = torch.norm(out - y, p=1) / torch.norm(y, p=1)

print(f'==Relative L1 error mean: {data_loss.item() : .6f}==\n')

# Plot
print("Ground Truth")
truth = y[0].detach().cpu().numpy()
x_grid = np.linspace(0, 1, truth.shape[1])

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(x_grid, truth[0], label="Initial")
plt.plot(x_grid, truth[-1], label="Final")
plt.title("Initial versus Final states")
plt.legend()

plt.subplot(1, 2, 2)
plt.imshow(truth, extent=[0, 1, 0, 1], origin="lower", aspect="auto", cmap="jet")
plt.title("Ground Truth Burgers nu=0.01")
plt.colorbar()

plt.tight_layout()
plt.show()

print("Prediction")
pred = out[0].detach().cpu().numpy()

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(x_grid, pred[0], label="Initial")
plt.plot(x_grid, pred[-1], label="Final")
plt.title("Initial versus Final states")
plt.legend()

plt.subplot(1, 2, 2)
plt.imshow(pred, extent=[0, 1, 0, 1], origin="lower", aspect="auto", cmap="jet")
plt.title("Ground Truth Burgers nu=0.01")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# Input shape:  torch.Size([1, 101, 100, 3])
# Output shape:  torch.Size([1, 101, 100])
#
#
# ==Relative L1 error mean:  0.025482==
#
# Ground Truth
# Prediction

# %%
dataset = BurgersLoader("/home/tp526/neuraloperator/data/burgers_pino.mat",
                            nx=128, nt=100,
                            sub=1, sub_t=1, new=True)
train_loader = dataset.make_loader(n_sample=10,
                                    batch_size=1,
                                    start=0)
# Out:
# /home/tp526/.conda/envs/dde/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:235: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Considerscipy.io.matlab.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)

# %%
for batch in train_loader:
    x, y = batch
    print(x.shape)
# Out:
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])
# torch.Size([1, 101, 128, 3])

# %%
import scipy

# We map 'x' -> 'input' and 'y' -> 'output'
mat_data = {
    'input': data_dict['x'],
    'output': data_dict['y'],
    'visc': data_dict['visc']
}

# 3. Save to .mat file
# do_compression=True helps if the arrays are large
scipy.io.savemat('/home/tp526/neuraloperator/data/traffic_pino.mat', mat_data, do_compression=True)

print("Saved to /home/tp526/neuraloperator/data/traffic_pino.mat")
# Out:
# Saved to /home/tp526/neuraloperator/data/traffic_pino.mat

# %%
print("-" * 100)
print("\nNumber of trainable parameters: ", sum(p.numel() for p in model.parameters()))
print("\n" + "-" * 100)
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Number of trainable parameters:  85937
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# <h2>Test</h2>

# %%
#model.eval()

N_CASE = formatted_inputs.shape[0]

l2_errors = np.zeros(N_CASE)
l1_errors = np.zeros(N_CASE)

with torch.no_grad():
    for k in range(N_CASE):
        x = torch.tensor(formatted_inputs[k:k+1], dtype=torch.float32).to(device)
        y = torch.tensor(data_dict["y"][k:k+1], dtype=torch.float32).to(device)

        out = model(x).reshape(y.shape)

        # Relative L2
        l2 = torch.norm(out - y, p=2) / torch.norm(y, p=2)
        l2_errors[k] = l2.item()

        # Relative L1
        l1 = torch.norm(out - y, p=1) / torch.norm(y, p=1)
        l1_errors[k] = l1.item()

        if (k+1) % 20 == 0:
            print(f'Sample {k+1}/{N_CASE}: ')
            print(f'    Mean L2-relative-error: {np.mean(l2_errors[:(k+1)]):.6e}')
            print(f'    Mean L1-relative-error: {np.mean(l1_errors[:(k+1)]):.6e}')
            print("-" * 50 + "\n")

print(f"Mean L2-relative-error over 100 tests: {np.mean(l2_errors):.6e}")
print(f"Mean L1-relative-error over 100 tests: {np.mean(l1_errors):.6e}")
print(f"L2 std: {np.std(l2_errors):.6e}")
print(f"L1 std: {np.std(l1_errors):.6e}")
# Out:
# Sample 20/1000:
#     Mean L2-relative-error: 5.009123e-02
#     Mean L1-relative-error: 3.006389e-02
# --------------------------------------------------
#
# Sample 40/1000:
#     Mean L2-relative-error: 4.588318e-02
#     Mean L1-relative-error: 2.679097e-02
# --------------------------------------------------
#
# Sample 60/1000:
#     Mean L2-relative-error: 4.861277e-02
#     Mean L1-relative-error: 2.763224e-02
# --------------------------------------------------
#
# Sample 80/1000:
#     Mean L2-relative-error: 4.971748e-02
#     Mean L1-relative-error: 2.838481e-02
# --------------------------------------------------
#
# Sample 100/1000:
#     Mean L2-relative-error: 5.055585e-02
#     Mean L1-relative-error: 2.868640e-02
# --------------------------------------------------
#
# Sample 120/1000:
#     Mean L2-relative-error: 5.142227e-02
#     Mean L1-relative-error: 2.892268e-02
# --------------------------------------------------
#
# Sample 140/1000:
#     Mean L2-relative-error: 5.034857e-02
#     Mean L1-relative-error: 2.832350e-02
# --------------------------------------------------
#
# Sample 160/1000:
#     Mean L2-relative-error: 4.980956e-02
#     Mean L1-relative-error: 2.793521e-02
# --------------------------------------------------
#
# Sample 180/1000:
#     Mean L2-relative-error: 4.935794e-02
#     Mean L1-relative-error: 2.768719e-02
# --------------------------------------------------
#
# Sample 200/1000:
#     Mean L2-relative-error: 4.934332e-02
#     Mean L1-relative-error: 2.762872e-02
# --------------------------------------------------
#
# Sample 220/1000:
#     Mean L2-relative-error: 5.005468e-02
#     Mean L1-relative-error: 2.791742e-02
# --------------------------------------------------
#
# Sample 240/1000:
#     Mean L2-relative-error: 5.053268e-02
#     Mean L1-relative-error: 2.809888e-02
# --------------------------------------------------
#
# Sample 260/1000:
#     Mean L2-relative-error: 4.988436e-02
#     Mean L1-relative-error: 2.770718e-02
# --------------------------------------------------
#
# Sample 280/1000:
#     Mean L2-relative-error: 4.936299e-02
#     Mean L1-relative-error: 2.737447e-02
# --------------------------------------------------
#
# Sample 300/1000:
#     Mean L2-relative-error: 4.909862e-02
#     Mean L1-relative-error: 2.712212e-02
# --------------------------------------------------
#
# Sample 320/1000:
#     Mean L2-relative-error: 4.878782e-02
#     Mean L1-relative-error: 2.706332e-02
# --------------------------------------------------
#
# Sample 340/1000:
#     Mean L2-relative-error: 4.879124e-02
#     Mean L1-relative-error: 2.707063e-02
# --------------------------------------------------
#
# Sample 360/1000:
#     Mean L2-relative-error: 4.896313e-02
#     Mean L1-relative-error: 2.717731e-02
# --------------------------------------------------
#
# Sample 380/1000:
#     Mean L2-relative-error: 4.951680e-02
#     Mean L1-relative-error: 2.747364e-02
# --------------------------------------------------
#
# Sample 400/1000:
#     Mean L2-relative-error: 4.915883e-02
#     Mean L1-relative-error: 2.728721e-02
# --------------------------------------------------
#
# Sample 420/1000:
#     Mean L2-relative-error: 4.871456e-02
#     Mean L1-relative-error: 2.704013e-02
# --------------------------------------------------
#
# Sample 440/1000:
#     Mean L2-relative-error: 4.828102e-02
#     Mean L1-relative-error: 2.679734e-02
# --------------------------------------------------
#
# Sample 460/1000:
#     Mean L2-relative-error: 4.812548e-02
#     Mean L1-relative-error: 2.672621e-02
# --------------------------------------------------
#
# Sample 480/1000:
#     Mean L2-relative-error: 4.807596e-02
#     Mean L1-relative-error: 2.675893e-02
# --------------------------------------------------
#
# Sample 500/1000:
#     Mean L2-relative-error: 4.812612e-02
#     Mean L1-relative-error: 2.674831e-02
# --------------------------------------------------
#
# Sample 520/1000:
#     Mean L2-relative-error: 4.811100e-02
#     Mean L1-relative-error: 2.671772e-02
# --------------------------------------------------
#
# Sample 540/1000:
#     Mean L2-relative-error: 4.846151e-02
#     Mean L1-relative-error: 2.692579e-02
# --------------------------------------------------
#
# Sample 560/1000:
#     Mean L2-relative-error: 4.806865e-02
#     Mean L1-relative-error: 2.673780e-02
# --------------------------------------------------
#
# Sample 580/1000:
#     Mean L2-relative-error: 4.842490e-02
#     Mean L1-relative-error: 2.695702e-02
# --------------------------------------------------
#
# Sample 600/1000:
#     Mean L2-relative-error: 4.841045e-02
#     Mean L1-relative-error: 2.693174e-02
# --------------------------------------------------
#
# Sample 620/1000:
#     Mean L2-relative-error: 4.865358e-02
#     Mean L1-relative-error: 2.702813e-02
# --------------------------------------------------
#
# Sample 640/1000:
#     Mean L2-relative-error: 4.885649e-02
#     Mean L1-relative-error: 2.708447e-02
# --------------------------------------------------
#
# Sample 660/1000:
#     Mean L2-relative-error: 4.878874e-02
#     Mean L1-relative-error: 2.704064e-02
# --------------------------------------------------
#
# Sample 680/1000:
#     Mean L2-relative-error: 4.838708e-02
#     Mean L1-relative-error: 2.686640e-02
# --------------------------------------------------
#
# Sample 700/1000:
#     Mean L2-relative-error: 4.841651e-02
#     Mean L1-relative-error: 2.687958e-02
# --------------------------------------------------
#
# Sample 720/1000:
#     Mean L2-relative-error: 4.822397e-02
#     Mean L1-relative-error: 2.677710e-02
# --------------------------------------------------
#
# Sample 740/1000:
#     Mean L2-relative-error: 4.811972e-02
#     Mean L1-relative-error: 2.672411e-02
# --------------------------------------------------
#
# Sample 760/1000:
#     Mean L2-relative-error: 4.815783e-02
#     Mean L1-relative-error: 2.674839e-02
# --------------------------------------------------
#
# Sample 780/1000:
#     Mean L2-relative-error: 4.810589e-02
#     Mean L1-relative-error: 2.670065e-02
# --------------------------------------------------
#
# Sample 800/1000:
#     Mean L2-relative-error: 4.806173e-02
#     Mean L1-relative-error: 2.666738e-02
# --------------------------------------------------
#
# Sample 820/1000:
#     Mean L2-relative-error: 4.797757e-02
#     Mean L1-relative-error: 2.659807e-02
# --------------------------------------------------
#
# Sample 840/1000:
#     Mean L2-relative-error: 4.794920e-02
#     Mean L1-relative-error: 2.655388e-02
# --------------------------------------------------
#
# Sample 860/1000:
#     Mean L2-relative-error: 4.805974e-02
#     Mean L1-relative-error: 2.665208e-02
# --------------------------------------------------
#
# Sample 880/1000:
#     Mean L2-relative-error: 4.797334e-02
#     Mean L1-relative-error: 2.665717e-02
# --------------------------------------------------
#
# Sample 900/1000:
#     Mean L2-relative-error: 4.811405e-02
#     Mean L1-relative-error: 2.670499e-02
# --------------------------------------------------
#
# Sample 920/1000:
#     Mean L2-relative-error: 4.808145e-02
#     Mean L1-relative-error: 2.666431e-02
# --------------------------------------------------
#
# Sample 940/1000:
#     Mean L2-relative-error: 4.810163e-02
#     Mean L1-relative-error: 2.670077e-02
# --------------------------------------------------
#
# Sample 960/1000:
#     Mean L2-relative-error: 4.809990e-02
#     Mean L1-relative-error: 2.669486e-02
# --------------------------------------------------
#
# Sample 980/1000:
#     Mean L2-relative-error: 4.787360e-02
#     Mean L1-relative-error: 2.659386e-02
# --------------------------------------------------
#
# Sample 1000/1000:
#     Mean L2-relative-error: 4.790029e-02
#     Mean L1-relative-error: 2.662614e-02
# --------------------------------------------------
#
# Mean L2-relative-error over 100 tests: 4.790029e-02
# Mean L1-relative-error over 100 tests: 2.662614e-02
# L2 std: 2.791835e-02
# L1 std: 1.490082e-02

# %%
#model.eval()

N_CASE = formatted_inputs.shape[0]

l2_errors = np.zeros(N_CASE)
l1_errors = np.zeros(N_CASE)

with torch.no_grad():
    for k in range(N_CASE):
        x = torch.tensor(formatted_inputs[k:k+1], dtype=torch.float32).to(device)
        y = torch.tensor(data_dict["y"][k:k+1], dtype=torch.float32).to(device)

        out = model(x).reshape(y.shape)

        # Relative L2
        l2 = torch.norm(out - y, p=2) / torch.norm(y, p=2)
        l2_errors[k] = l2.item()

        # Relative L1
        l1 = torch.norm(out - y, p=1) / torch.norm(y, p=1)
        l1_errors[k] = l1.item()

        if (k+1) % 20 == 0:
            print(f'Sample {k+1}/{N_CASE}: ')
            print(f'    Mean L2-relative-error: {np.mean(l2_errors[:(k+1)]):.6e}')
            print(f'    Mean L1-relative-error: {np.mean(l1_errors[:(k+1)]):.6e}')
            print("-" * 50 + "\n")

print(f"Mean L2-relative-error over 100 tests: {np.mean(l2_errors):.6e}")
print(f"Mean L1-relative-error over 100 tests: {np.mean(l1_errors):.6e}")
print(f"L2 std: {np.std(l2_errors):.6e}")
print(f"L1 std: {np.std(l1_errors):.6e}")
# Out:
# Sample 20/1000:
#     Mean L2-relative-error: 2.878800e-01
#     Mean L1-relative-error: 2.055837e-01
# --------------------------------------------------
#
# Sample 40/1000:
#     Mean L2-relative-error: 2.920497e-01
#     Mean L1-relative-error: 2.107693e-01
# --------------------------------------------------
#
# Sample 60/1000:
#     Mean L2-relative-error: 3.033791e-01
#     Mean L1-relative-error: 2.178382e-01
# --------------------------------------------------
#
# Sample 80/1000:
#     Mean L2-relative-error: 3.023997e-01
#     Mean L1-relative-error: 2.156428e-01
# --------------------------------------------------
#
# Sample 100/1000:
#     Mean L2-relative-error: 3.078089e-01
#     Mean L1-relative-error: 2.194434e-01
# --------------------------------------------------
#
# Sample 120/1000:
#     Mean L2-relative-error: 3.085471e-01
#     Mean L1-relative-error: 2.193732e-01
# --------------------------------------------------
#
# Sample 140/1000:
#     Mean L2-relative-error: 3.073825e-01
#     Mean L1-relative-error: 2.198563e-01
# --------------------------------------------------
#
# Sample 160/1000:
#     Mean L2-relative-error: 3.076244e-01
#     Mean L1-relative-error: 2.193529e-01
# --------------------------------------------------
#
# Sample 180/1000:
#     Mean L2-relative-error: 3.080359e-01
#     Mean L1-relative-error: 2.208061e-01
# --------------------------------------------------
#
# Sample 200/1000:
#     Mean L2-relative-error: 3.071650e-01
#     Mean L1-relative-error: 2.207656e-01
# --------------------------------------------------
#
# Sample 220/1000:
#     Mean L2-relative-error: 3.091304e-01
#     Mean L1-relative-error: 2.221590e-01
# --------------------------------------------------
#
# Sample 240/1000:
#     Mean L2-relative-error: 3.078418e-01
#     Mean L1-relative-error: 2.212306e-01
# --------------------------------------------------
#
# Sample 260/1000:
#     Mean L2-relative-error: 3.058801e-01
#     Mean L1-relative-error: 2.194595e-01
# --------------------------------------------------
#
# Sample 280/1000:
#     Mean L2-relative-error: 3.040092e-01
#     Mean L1-relative-error: 2.183638e-01
# --------------------------------------------------
#
# Sample 300/1000:
#     Mean L2-relative-error: 3.040863e-01
#     Mean L1-relative-error: 2.183689e-01
# --------------------------------------------------
#
# Sample 320/1000:
#     Mean L2-relative-error: 3.011568e-01
#     Mean L1-relative-error: 2.162771e-01
# --------------------------------------------------
#
# Sample 340/1000:
#     Mean L2-relative-error: 2.990200e-01
#     Mean L1-relative-error: 2.143892e-01
# --------------------------------------------------
#
# Sample 360/1000:
#     Mean L2-relative-error: 2.956028e-01
#     Mean L1-relative-error: 2.124378e-01
# --------------------------------------------------
#
# Sample 380/1000:
#     Mean L2-relative-error: 2.944470e-01
#     Mean L1-relative-error: 2.119319e-01
# --------------------------------------------------
#
# Sample 400/1000:
#     Mean L2-relative-error: 2.954331e-01
#     Mean L1-relative-error: 2.126635e-01
# --------------------------------------------------
#
# Sample 420/1000:
#     Mean L2-relative-error: 2.960827e-01
#     Mean L1-relative-error: 2.127799e-01
# --------------------------------------------------
#
# Sample 440/1000:
#     Mean L2-relative-error: 2.975339e-01
#     Mean L1-relative-error: 2.135941e-01
# --------------------------------------------------
#
# Sample 460/1000:
#     Mean L2-relative-error: 2.952183e-01
#     Mean L1-relative-error: 2.120735e-01
# --------------------------------------------------
#
# Sample 480/1000:
#     Mean L2-relative-error: 2.960357e-01
#     Mean L1-relative-error: 2.125191e-01
# --------------------------------------------------
#
# Sample 500/1000:
#     Mean L2-relative-error: 2.967650e-01
#     Mean L1-relative-error: 2.130841e-01
# --------------------------------------------------
#
# Sample 520/1000:
#     Mean L2-relative-error: 2.966775e-01
#     Mean L1-relative-error: 2.126781e-01
# --------------------------------------------------
#
# Sample 540/1000:
#     Mean L2-relative-error: 2.966407e-01
#     Mean L1-relative-error: 2.125346e-01
# --------------------------------------------------
#
# Sample 560/1000:
#     Mean L2-relative-error: 2.966060e-01
#     Mean L1-relative-error: 2.125253e-01
# --------------------------------------------------
#
# Sample 580/1000:
#     Mean L2-relative-error: 2.969227e-01
#     Mean L1-relative-error: 2.127025e-01
# --------------------------------------------------
#
# Sample 600/1000:
#     Mean L2-relative-error: 2.954777e-01
#     Mean L1-relative-error: 2.117686e-01
# --------------------------------------------------
#
# Sample 620/1000:
#     Mean L2-relative-error: 2.953675e-01
#     Mean L1-relative-error: 2.118163e-01
# --------------------------------------------------
#
# Sample 640/1000:
#     Mean L2-relative-error: 2.951142e-01
#     Mean L1-relative-error: 2.121023e-01
# --------------------------------------------------
#
# Sample 660/1000:
#     Mean L2-relative-error: 2.952680e-01
#     Mean L1-relative-error: 2.122450e-01
# --------------------------------------------------
#
# Sample 680/1000:
#     Mean L2-relative-error: 2.948227e-01
#     Mean L1-relative-error: 2.119303e-01
# --------------------------------------------------
#
# Sample 700/1000:
#     Mean L2-relative-error: 2.948147e-01
#     Mean L1-relative-error: 2.119515e-01
# --------------------------------------------------
#
# Sample 720/1000:
#     Mean L2-relative-error: 2.936548e-01
#     Mean L1-relative-error: 2.111880e-01
# --------------------------------------------------
#
# Sample 740/1000:
#     Mean L2-relative-error: 2.933961e-01
#     Mean L1-relative-error: 2.111770e-01
# --------------------------------------------------
#
# Sample 760/1000:
#     Mean L2-relative-error: 2.934311e-01
#     Mean L1-relative-error: 2.115230e-01
# --------------------------------------------------
#
# Sample 780/1000:
#     Mean L2-relative-error: 2.931179e-01
#     Mean L1-relative-error: 2.109764e-01
# --------------------------------------------------
#
# Sample 800/1000:
#     Mean L2-relative-error: 2.920522e-01
#     Mean L1-relative-error: 2.102994e-01
# --------------------------------------------------
#
# Sample 820/1000:
#     Mean L2-relative-error: 2.928012e-01
#     Mean L1-relative-error: 2.109071e-01
# --------------------------------------------------
#
# Sample 840/1000:
#     Mean L2-relative-error: 2.933447e-01
#     Mean L1-relative-error: 2.112623e-01
# --------------------------------------------------
#
# Sample 860/1000:
#     Mean L2-relative-error: 2.937714e-01
#     Mean L1-relative-error: 2.117680e-01
# --------------------------------------------------
#
# Sample 880/1000:
#     Mean L2-relative-error: 2.938611e-01
#     Mean L1-relative-error: 2.116632e-01
# --------------------------------------------------
#
# Sample 900/1000:
#     Mean L2-relative-error: 2.935665e-01
#     Mean L1-relative-error: 2.113755e-01
# --------------------------------------------------
#
# Sample 920/1000:
#     Mean L2-relative-error: 2.938366e-01
#     Mean L1-relative-error: 2.114560e-01
# --------------------------------------------------
#
# Sample 940/1000:
#     Mean L2-relative-error: 2.942278e-01
#     Mean L1-relative-error: 2.118410e-01
# --------------------------------------------------
#
# Sample 960/1000:
#     Mean L2-relative-error: 2.940692e-01
#     Mean L1-relative-error: 2.115009e-01
# --------------------------------------------------
#
# Sample 980/1000:
#     Mean L2-relative-error: 2.940055e-01
#     Mean L1-relative-error: 2.112777e-01
# --------------------------------------------------
#
# Sample 1000/1000:
#     Mean L2-relative-error: 2.942337e-01
#     Mean L1-relative-error: 2.114662e-01
# --------------------------------------------------
#
# Mean L2-relative-error over 100 tests: 2.942337e-01
# Mean L1-relative-error over 100 tests: 2.114662e-01
# L2 std: 1.130555e-01
# L1 std: 8.125450e-02
